# %% [markdown]
# **Simple Linear Regression using Sklearn**
# https://www.kaggle.com/ksekhark/simple-linear-regression-using-sklearn/notebook

# %%
## Regularized Linear Models

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Import Library**

# %%
## Import Library
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt # Plotting and Visualizing data

# %% [markdown]
# **Datasets**

# %%
data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Tugas ML/Colab ML/Colab/Week 2 Simple Linear Regression using Sklearn/train.csv')
print(data.describe())

data = data[data.x <= 100]
# Out:
#                  x           y
# count   700.000000  699.000000
# mean     54.985939   49.939869
# std     134.681703   29.109217
# min       0.000000   -3.839981
# 25%      25.000000   24.929968
# 50%      49.000000   48.973020
# 75%      75.000000   74.929911
# max    3530.157369  108.871618

# %% [markdown]
# **Separating Dependent & Indepented Variables**

# %%
x = data.iloc[:, 0:1].values
y = data.iloc[:, 1]

# %%
# Train Test Split
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.33)
print(x[:10])
print('\n')
print(y[:10])
# Out:
# [[24.]
#  [50.]
#  [15.]
#  [38.]
#  [87.]
#  [36.]
#  [12.]
#  [81.]
#  [25.]
#  [ 5.]]
#
#
# 0    21.549452
# 1    47.464463
# 2    17.218656
# 3    36.586398
# 4    87.288984
# 5    32.463875
# 6    10.780897
# 7    80.763399
# 8    24.612151
# 9     6.963319
# Name: y, dtype: float64

# %% [markdown]
# **Model Import and Build**

# %%
from sklearn.linear_model import LinearRegression

regressor = LinearRegression()
regressor.fit(x_train, y_train)

pred = regressor.predict(x_test)

# %% [markdown]
# **Visualization**

# %%
plt.scatter(x_train, y_train)
plt.plot(x_train, regressor.predict(x_train), color='black')
plt.title('Fit on training set')
plt.xlabel('X-Train')
plt.ylabel('Y-Train')
# Out:
# Text(0, 0.5, 'Y-Train')

# %% [markdown]
# **Fitting on Validation Set**

# %%
plt.scatter(x_test, y_test, color='r')
plt.plot(x_test, pred, color='b')
plt.title('Validation set')
plt.xlabel('X-Test')
plt.ylabel('Y-Test')
# Out:
# Text(0, 0.5, 'Y-Test')

# %% [markdown]
# **Final Test Set**

# %%
test = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Tugas ML/Colab ML/Colab/Week 2 Simple Linear Regression using Sklearn/test.csv')
test.plot.scatter('x', 'y', color='g')
plt.plot(test['x'], regressor.predict(test.iloc[:,0:1].values), color='blue')
plt.title('Linear Regression Ouput on Test Data Set')
plt.xlabel('X-Values')
plt.ylabel('Y-Values')
plt.show()
